# %%
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\bhupe\Downloads\Advertising.csv",index_col=0)

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %% [markdown]
# # outlier

# %%
x= data["TV"]
y=data["sales"]

# %%
plt.scatter(x,y)
plt.xlabel("TV")
plt.ylabel("sales")
plt.title("sales VS Tv Adevertising")
# Out:
# Text(0.5, 1.0, 'sales VS radio Adevertising')

# %%
x= data["radio"]
y=data["sales"]


plt.scatter(x,y)
plt.xlabel("radio")
plt.ylabel("sales")
plt.title("sales VS radio Adevertising")
# Out:
# Text(0.5, 1.0, 'sales VS radio Adevertising')

# %%
x= data["newspaper"]
y=data["sales"]


plt.scatter(x,y)
plt.xlabel("newspaper")
plt.ylabel("sales")
plt.title("sales VS newspaper Adevertising")
# Out:
# Text(0.5, 1.0, 'sales VS newspaper Adevertising')

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
data.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
plt.boxplot(data["newspaper"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x22ebf5a4a60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x22ebf5a4760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x22ebeee1e10>],
#  'medians': [<matplotlib.lines.Line2D at 0x22ec0d56a70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x22ec0d55480>],
#  'means': []}

# %% [markdown]
# # Training testing ratio - 80:20, 70:30
#
# Linear Regrssion formula -  y=b0+b1x1

# %%
x =  data[["TV","radio","newspaper"]]
y =  data[["sales"]]

# %%
x
# Out:
#         TV  radio  newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
#      sales
# 1     22.1
# 2     10.4
# 3      9.3
# 4     18.5
# 5     12.9
# ..     ...
# 196    7.6
# 197    9.7
# 198   12.8
# 199   25.5
# 200   13.4
#
# [200 rows x 1 columns]

# %%
import sklearn

# %%
print("shape of x",x.shape)
print("shape of y",y.shape)
# Out:
# shape of x (200, 3)
# shape of y (200, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.20)

# %%
print("the shape of x-train",x_train.shape)
print("the shape of x-test",x_test.shape)
print("the shape of y-train",y_train.shape)
print("the shape of y-test",y_test.shape)
# Out:
# the shape of x-train (160, 3)
# the shape of x-test (40, 3)
# the shape of y-train (160, 1)
# the shape of y-test (40, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
model = lm.fit(x_train,y_train)

# %%
print(lm.coef_)
# Out:
# [[ 0.04693038  0.18893435 -0.00129944]]

# %%
print(lm.intercept_)
# Out:
# [2.76331976]

# %% [markdown]
# # y = b0 + b1x1  + b2x2 + b3x3

# %%
bzero =  2.76331976

# %%
bone = 0.04693038

# %%
btwo = 0.18893435

# %%
bthree = -0.00129944

# %%
y =  bzero + bone*228 + btwo*37.7 + bthree*32

# %%
y
# Out:
# 20.544689315

# %%
y_pred = lm.predict(x_test)

# %%
new_df = pd.DataFrame()
new_df = x_test
new_df['actual sales'] =  y_test
new_df['predicted sales'] = y_pred
new_df
# Out:
#         TV  radio  newspaper  actual sales  predicted sales
# 64   102.7   29.6        8.4          14.0        13.164611
# 74   129.4    5.7       31.3          11.0         9.872364
# 103  280.2   10.1       21.4          14.8        17.793640
# 14    97.5    7.6        7.2           9.7         8.765576
# 162   85.7   35.8       49.3          13.3        13.485040
# 141   73.4   17.0       12.9          10.9         9.403130
# 20   147.3   23.9       19.1          14.6        14.166876
# 136   48.3   47.0        8.5          11.6        13.898926
# 73    26.8   33.0       19.3           8.8        10.230808
# 36   290.7    4.1        8.5          12.8        17.169565
# 40   228.0   37.7       32.0          21.5        20.544688
# 83    75.3   20.3       32.5          11.3        10.090312
# 138  273.7   28.9       59.7          20.8        20.990789
# 121  141.3   26.8       46.2          15.5        14.397988
# 192   75.5   10.8        6.0           9.9         8.339257
# ...

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

r2=r2_score(y_test,y_pred)
print("R-squared:",r2*100)

rmse=np.sqrt(mean_squared_error(y_test,y_pred))
print("RMSE:",rmse)
# Out:
# R-squared: 87.4079771743226
# RMSE: 1.7737997619365906

# %%
new_df.to_csv("uodated.csv")
